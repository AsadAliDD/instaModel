# %%
import torch

# %%
ckpt=torch.load('/home/valkyrie/instaModelWorkspace/Workspace/instaModel/lightning_logs/version_57/checkpoints/epoch=40-step=1886.ckpt')

# %%
ckpt
# Out:
# {'epoch': 40,
#  'global_step': 1886,
#  'pytorch-lightning_version': '1.9.2',
#  'state_dict': OrderedDict([('model.model.0.weight',
#                tensor([[[[-6.3942e-03, -5.2077e-03,  3.5855e-02,  ...,  4.7622e-02,
#                           -1.8319e-02,  1.1060e-02],
#                          [-5.7675e-02,  4.1390e-02,  7.4565e-02,  ...,  8.7975e-02,
#                            3.0574e-02, -5.6974e-02],
#                          [ 6.9623e-02, -2.7173e-01,  4.0277e-01,  ..., -1.6422e-01,
#                            2.2136e-01, -7.0026e-02],
#                          ...,
#                          [-1.0620e-01,  3.8242e-01, -4.5339e-01,  ...,  6.8737e-01,
#                           -5.7407e-01,  2.2968e-01],
#                          [ 3.1107e-02, -1.7455e-01,  6.4663e-01,  ...,  5.2997e-01,
#                           -4.3891e-02, -6.3119e-02],
#                          [ 5.0769e-02, -1.2858e-01,  2.1219e-02,  ..., -3.5479e-01,
# ...
